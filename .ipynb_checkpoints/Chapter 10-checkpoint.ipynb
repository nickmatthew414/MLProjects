# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets.mnist import load_data
import numpy as np

# %%
(X_train_full, y_train_full), (X_test_full, y_test_full) = load_data()

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(X_train_full[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test_full = X_test_full / 255.

# %%
n_rows = 4
n_cols = 10

plt.figure(figsize=(n_cols*1.2, n_rows*1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols*row + col
        plt.subplot(n_rows, n_cols, index+1)
        plt.imshow(X_train[index], cmap='binary', interpolation='nearest')
        plt.axis('off')
        plt.title(y_train[index], fontsize=12)
plt.subplots_adjust(wspace=.2, hspace=.5)
plt.show()

# %%
K = keras.backend

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses=[]    
    def on_batch_end(self, batches, logs):
        self.rates.append(K.get_value(self.model.optimizer.lr))
        self.losses.append(logs['loss'])
        K.set_value(self.model.optimizer.lr, self.model.optimizer.lr*self.factor)

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(units=300, activation = tf.nn.relu),
    keras.layers.Dense(units=100, activation=tf.nn.relu),
    keras.layers.Dense(units=10, activation=tf.nn.softmax)
                         ])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=keras.optimizers.SGD(lr=1e-3), metrics=['accuracy'])
expon_lr = ExponentialLearningRate(factor=1.005)

# %%
history = model.fit(X_train, y_train, epochs=1, validation_data=(X_valid, y_valid), callbacks=[expon_lr])
# Out:
# Train on 55000 samples, validate on 5000 samples
# 55000/55000 [==============================] - 6s 110us/sample - loss: 186017371896189312.0000 - accuracy: 0.5945 - val_loss: 2.3660 - val_accuracy: 0.1100

# %%
plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.xlabel('Learning Rate')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=keras.optimizers.SGD(lr=2e-1), metrics=['accuracy'])

# %%
import os
run_index = 1 # increment this at every run
run_logdir = os.path.join(os.curdir, "my_mnist_logs", "run_{:03d}".format(run_index))
run_logdir
# Out:
# './my_mnist_logs/run_001'

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=20)
checkpoint_cb = keras.callbacks.ModelCheckpoint('my_mnist_model.h5', save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping_cb, checkpoint_cb, tensorboard_cb], verbose=2)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/100
# 55000/55000 - 5s - loss: 0.2363 - accuracy: 0.9277 - val_loss: 0.1144 - val_accuracy: 0.9656
# Epoch 2/100
# 55000/55000 - 5s - loss: 0.0954 - accuracy: 0.9704 - val_loss: 0.0872 - val_accuracy: 0.9742
# Epoch 3/100
# 55000/55000 - 5s - loss: 0.0642 - accuracy: 0.9799 - val_loss: 0.0786 - val_accuracy: 0.9774
# Epoch 4/100
# 55000/55000 - 5s - loss: 0.0476 - accuracy: 0.9845 - val_loss: 0.0812 - val_accuracy: 0.9772
# Epoch 5/100
# 55000/55000 - 5s - loss: 0.0329 - accuracy: 0.9896 - val_loss: 0.3435 - val_accuracy: 0.9238
# Epoch 6/100
# 55000/55000 - 5s - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.0787 - val_accuracy: 0.9814
# Epoch 7/100
# 55000/55000 - 5s - loss: 0.0212 - accuracy: 0.9929 - val_loss: 0.0742 - val_accuracy: 0.9820
# Epoch 8/100
# 55000/55000 - 5s - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.0758 - val_accuracy: 0.9828
# Epoch 9/100
# 55000/55000 - 6s - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0786 - val_accuracy: 0.9822
# Epoch 10/100
# 55000/55000 - 6s - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0829 - val_accuracy: 0.9824
# Epoch 11/100
# 55000/55000 - 5s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0708 - val_accuracy: 0.9838
# Epoch 12/100
# 55000/55000 - 5s - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0729 - val_accuracy: 0.9856
# Epoch 13/100
# 55000/55000 - 5s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0727 - val_accuracy: 0.9858
# Epoch 14/100
# 55000/55000 - 5s - loss: 8.1817e-04 - accuracy: 0.9999 - val_loss: 0.0724 - val_accuracy: 0.9856
# Epoch 15/100
# 55000/55000 - 5s - loss: 2.8303e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9862
# Epoch 16/100
# 55000/55000 - 5s - loss: 2.1072e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9848
# Epoch 17/100
# 55000/55000 - 5s - loss: 1.8184e-04 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9860
# Epoch 18/100
# 55000/55000 - 5s - loss: 1.5916e-04 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9852
# Epoch 19/100
# 55000/55000 - 5s - loss: 1.4424e-04 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9856
# Epoch 20/100
# 55000/55000 - 5s - loss: 1.3122e-04 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9858
# Epoch 21/100
# 55000/55000 - 5s - loss: 1.2217e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9862
# Epoch 22/100
# 55000/55000 - 5s - loss: 1.1406e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9862
# Epoch 23/100
# 55000/55000 - 5s - loss: 1.0576e-04 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9864
# Epoch 24/100
# 55000/55000 - 5s - loss: 9.9755e-05 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9860
# Epoch 25/100
# 55000/55000 - 5s - loss: 9.4534e-05 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9862
# Epoch 26/100
# 55000/55000 - 5s - loss: 8.9557e-05 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9862
# Epoch 27/100
# 55000/55000 - 6s - loss: 8.5329e-05 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9866
# Epoch 28/100
# 55000/55000 - 5s - loss: 8.1307e-05 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9866
# Epoch 29/100
# 55000/55000 - 5s - loss: 7.7550e-05 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 0.9860
# Epoch 30/100
# 55000/55000 - 5s - loss: 7.4359e-05 - accuracy: 1.0000 - val_loss: 0.0808 - val_accuracy: 0.9860
# Epoch 31/100
# 55000/55000 - 5s - loss: 7.1585e-05 - accuracy: 1.0000 - val_loss: 0.0810 - val_accuracy: 0.9864

# %%
model = keras.models.load_model('my_mnist_model.h5') # rollback to best model
model.evaluate(X_test_full, y_test_full)
# Out:
# 10000/10000 [==============================] - 1s 63us/sample - loss: 0.0885 - accuracy: 0.9800s - loss: 0.0948 - accuracy: 0.
# [0.08849425183207213, 0.98]

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./path_to_your_logs --port=6006
# Out:
#       <iframe id="tensorboard-frame-9bee3f2b09162015" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9bee3f2b09162015");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
